# %%
#Import packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import copy
import warnings
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score,accuracy_score,recall_score,precision_score
from sklearn.preprocessing import label_binarize
import pickle
from MVDD.MVDD import MVDD
import MVDD.MVDD_Generator as mvGen

plt.rc('font', size=12)
warnings.filterwarnings('ignore')

# %%
#HELPER CODE

#Validation Method
def performValidation(model, data, realScores, aucName):
    #DT Accuracy
    print("*****DECISION TREE*****")
    y_pred = model.predictDTScoreSet(data)
    
    acc = accuracy_score(realScores,y_pred)
    recall = recall_score(realScores,y_pred,average='weighted')
    f1 = f1_score(realScores,y_pred,average='weighted')
    prec = precision_score(realScores,y_pred,average='weighted')
    
    #ROC AUC Score
    y_score = label_binarize(y_pred, classes=[1,2,3,4,5])
    y_test = label_binarize(realScores, classes=[1,2,3,4,5])
    fpr, tpr, roc_auc = mvGen.getClassROC(y_test,y_score)
    
    mvGen.getAverageROCGraph(fpr, tpr, roc_auc, aucName)

    print("DT Accuracy:", acc)
    print("DT Recall:", recall)
    print("DT F1 Score:", f1)
    print("DT Precision:", prec)
    
    #MVDD Accuracy
    print("\n*****MVDD*****")
    y_pred = model.predictScoreSet(data)
    
    acc = accuracy_score(realScores,y_pred)
    recall = recall_score(realScores,y_pred,average='weighted')
    f1 = f1_score(realScores,y_pred,average='weighted')
    prec = precision_score(realScores,y_pred,average='weighted')
    
    #ROC AUC Score
    y_score = label_binarize(y_pred, classes=[1,2,3,4,5])
    y_test = label_binarize(realScores, classes=[1,2,3,4,5])
    fpr, tpr, roc_auc = mvGen.getClassROC(y_test,y_score)
    
    mvGen.getAverageROCGraph(fpr, tpr, roc_auc, aucName)

    print("Accuracy:", acc)
    print("Recall:", recall)
    print("F1 Score:", f1)
    print("Precision:", prec)
    
    return acc, recall, f1, prec

# %% [markdown]
# # ESCAPE training - Hemo - Death

# %%
#Load original dataframes
hemoData = pd.read_csv('Data/Preprocessed Data/ESCAPE_AC_Hemo.csv', index_col='ID')
allScores = hemoData['Score']
death = hemoData['ScoreDeath']
rehosp = hemoData['ScoreRehosp']
readm = hemoData['ScoreReadmission']
hemoData
# Out:
#         Age  Gender  Race   EjF   RAP   PAS   PAD  PAMN  PCWP    CO  ...  \
# ID                                                                   ...
# 72     88.0     2.0   1.0  25.0  24.0  42.0  24.0  30.0  36.0  2.20  ...
# 72     88.0     2.0   1.0  25.0  18.0  42.0  24.0  30.0  24.0  3.10  ...
# 81     69.0     1.0   1.0  20.0  10.0  40.0  20.0  27.0  18.0  4.52  ...
# 81     69.0     1.0   1.0  20.0  12.0  35.0  15.0  25.0  17.0  4.65  ...
# 814    58.0     1.0   1.0   NaN   3.0  51.0  19.0  30.0  18.0  4.10  ...
# ...     ...     ...   ...   ...   ...   ...   ...   ...   ...   ...  ...
# 98508  57.0     1.0  98.0  30.0   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 99302  41.0     1.0   2.0  15.0  19.0  87.0  37.0  54.0  44.0  3.90  ...
# 99302  41.0     1.0   2.0  15.0  11.0  70.0  28.0  44.0  28.0  5.30  ...
# 99935  64.0     2.0   1.0  20.0   8.0  49.0  29.0  31.0  15.0  4.00  ...
# 99935  64.0     2.0   1.0  20.0   8.0  52.0  24.0  39.0  24.0  5.60  ...
#
#             RAT   PPRatio       PAPi      SAPi   CPP    PRAPRat  Score  \
# ID
# 72     0.666667  0.266667   0.750000  0.777778  50.0   1.166667      2
# 72     0.750000  0.272727   1.000000  1.000000  50.0   1.333333      2
# 81     0.555556  0.242857   2.000000  0.944444  45.0   1.700000      1
# 81     0.705882  0.571429   1.666667  2.352941  45.0   3.333333      1
# 814    0.166667  0.566667  10.666667  1.888889  44.0  11.333333      3
# ...         ...       ...        ...       ...   ...        ...    ...
# 98508       NaN       NaN        NaN       NaN  37.0        NaN      4
# 99302  0.431818  0.642857   2.631579  1.227273  13.0   2.842105      5
# 99302  0.392857  1.088608   3.818182  3.071429  13.0   7.818182      5
# 99935  0.533333  1.253333   2.500000  6.266667  30.0  11.750000      2
# 99935  0.333333  0.888889   3.500000  3.000000  30.0   9.000000      2
#
#        ScoreDeath  ScoreRehosp  ScoreReadmission
# ID
# 72              3            3                 2
# 72              3            3                 2
# 81              1            2                 1
# 81              1            2                 1
# 814             2            4                 4
# ...           ...          ...               ...
# 98508           5            1                 5
# 99302           4            5                 3
# 99302           4            5                 3
# 99935           3            3                 2
# 99935           3            3                 2
#
# [418 rows x 32 columns]

# %%
# Preprocess and create training and testing sets
hemo = hemoData.drop('Score', axis=1)
hemo = hemo.drop('ScoreDeath', axis=1)
hemo = hemo.drop('ScoreRehosp', axis=1)
hemo = hemo.drop('ScoreReadmission', axis=1)
hemo = hemo.replace(np.inf, 0)
hemo = hemo.fillna(0)

xData = hemo
yData = death
xData.shape, yData.shape
# Out:
# ((418, 28), (418,))

# %%
mvdd= mvGen.generateTreeCrossValidation(xData=xData, yData=yData, classes=["1", "2", "3", "4", "5"], 
                                        learningCriteria='gini', maxLevels=None, minSamplesPerLeaf=1, 
                                        modelName='AC_Hemo_Death', numFolds=5, 
                                        showIndividualROC=True)
# Out:
# Total edges: 56 Nonterminal Edge 27
# Must have more than 8 and less than 16 OR Edges
# Best edge set: ['dashed', 'dashed', 'dashed', 'dashed', 'dashed', 'dashed', 'dashed', 'dashed', 'solid', 'solid', 'solid', 'solid', 'solid', 'solid', 'solid', 'solid', 'dashed', 'solid', 'solid', 'solid', 'solid', 'solid', 'solid', 'solid', 'solid', 'solid', 'solid']
# Accuracy DT: 0.8809523809523809
# Accuracy MVDD: 0.44047619047619047
#
# Total edges: 56 Nonterminal Edge 27
# Must have more than 8 and less than 16 OR Edges
# Best edge set: ['dashed', 'dashed', 'dashed', 'dashed', 'dashed', 'dashed', 'dashed', 'dashed', 'solid', 'dashed', 'solid', 'solid', 'solid', 'solid', 'solid', 'solid', 'solid', 'solid', 'solid', 'solid', 'solid', 'solid', 'solid', 'solid', 'solid', 'solid', 'solid']
# Accuracy DT: 0.8452380952380952
# Accuracy MVDD: 0.3333333333333333
#
# Total edges: 62 Nonterminal Edge 30
# Must have more than 9 and less than 18 OR Edges
# Best edge set: ['dashed', 'dashed', 'dashed', 'dashed', 'dashed', 'dashed', 'dashed', 'dashed', 'dashed', 'dashed', 'solid', 'solid', 'solid', 'solid', 'solid', 'solid', 'solid', 'solid', 'solid', 'solid', 'solid', 'solid', 'solid', 'solid', 'solid', 'solid', 'solid', 'solid', 'solid', 'solid']
# Accuracy DT: 0.8809523809523809
# Accuracy MVDD: 0.40476190476190477
#
# Total edges: 62 Nonterminal Edge 30
# Must have more than 9 and less than 18 OR Edges
# Best edge set: ['dashed', 'dashed', 'dashed', 'dashed', 'dashed', 'dashed', 'dashed', 'dashed', 'dashed', 'dashed', 'solid', 'solid', 'solid', 'solid', 'solid', 'solid', 'solid', 'solid', 'solid', 'dashed', 'solid', 'solid', 'solid', 'solid', 'solid', 'solid', 'solid', 'solid', 'solid', 'solid']
# Accuracy DT: 0.8674698795180723
# Accuracy MVDD: 0.42168674698795183
#
# Total edges: 60 Nonterminal Edge 29
# Must have more than 9 and less than 17 OR Edges
# Best edge set: ['dashed', 'dashed', 'dashed', 'dashed', 'dashed', 'dashed', 'dashed', 'dashed', 'dashed', 'dashed', 'solid', 'solid', 'solid', 'solid', 'solid', 'solid', 'solid', 'solid', 'solid', 'solid', 'solid', 'solid', 'solid', 'solid', 'solid', 'solid', 'solid', 'solid', 'solid']
# Accuracy DT: 0.7831325301204819
# Accuracy MVDD: 0.3373493975903614
# *****Averaged Final Classification Results*****
# Accuracy: 0.388(+/- 0.088)
# Precision: 0.276(+/- 0.088)
# Recall: 0.388(+/- 0.088)
# F1: 0.289(+/- 0.100)

# %% [markdown]
# ## Cardiogenic Shock Validation

# %%
testModel = mvGen.loadMVDDFromFile('TreeFiles/AC_Hemo_Death')

# %%
hemoCohort = pd.read_csv("Data Validation/Cardiogenic Shock/Preprocessed Data/CardiogenicShock_AC_Hemo.csv", sep=",", index_col='ID')
deathLabels = hemoCohort['ScoreDeath']

hemo = hemoCohort.drop('ScoreDeath', axis=1)
hemo = hemo.drop('Score', axis=1)
hemo = hemo.drop('ScoreRehosp', axis=1)
hemo = hemo.drop('ScoreReadmission', axis=1)
hemo = hemo.replace(np.inf, 0)
hemo = hemo.fillna(0)

#get predicted scores from model
acc, recall, f1, prec = performValidation(model=testModel, data=hemo, realScores=deathLabels, aucName='HemoCardShock')
# Out:
# *****DECISION TREE*****
# DT Accuracy: 0.756578947368421
# DT Recall: 0.756578947368421
# DT F1 Score: 0.7595645542929093
# DT Precision: 0.7730370569280345
#
# *****MVDD*****
# Accuracy: 0.40131578947368424
# Recall: 0.40131578947368424
# F1 Score: 0.31011029411764707
# Precision: 0.25632698768197093

# %% [markdown]
# # ESCAPE Training - All Data - Death

# %%
#Load original dataframes
allData = pd.read_csv('Data/Preprocessed Data/ESCAPE_AC_AllData.csv', index_col='ID')
allScores = allData['Score']
death = allData['ScoreDeath']
rehosp = allData['ScoreRehosp']
readm = allData['ScoreReadmission']
allData
# Out:
#         Age  Gender  Race          Wt        BMI  InitialHospDays  \
# ID
# 72     88.0     2.0   1.0   57.100000  26.424175              9.0
# 72     88.0     2.0   1.0   52.000000  24.064047              9.0
# 81     69.0     1.0   1.0  102.363636  32.307675              5.0
# 81     69.0     1.0   1.0  100.454545  31.705134              5.0
# 86     56.0     2.0   2.0   98.636364  40.016375              3.0
# ...     ...     ...   ...         ...        ...              ...
# 99302  41.0     1.0   2.0   97.400000  40.541103             21.0
# 99912  46.0     1.0   1.0   78.636364  25.677180              2.0
# 99912  46.0     1.0   1.0   78.200000  25.534694              2.0
# 99935  64.0     2.0   1.0   77.700000  32.762692              3.0
# 99935  64.0     2.0   1.0         NaN        NaN              3.0
#
#        TotalHospDays  NYHA  MLHFS   AF  ...     HR         PV         MAP  \
# ID                                      ...
# 72              16.0   4.0   76.0  1.0  ...  104.0  12.452563  139.333333
# 72              16.0   3.0   76.0  1.0  ...   92.0  12.452563  126.000000
# 81              13.0   4.0   21.0  1.0  ...   70.0  -3.346568  125.333333
# 81              13.0   2.0   21.0  1.0  ...   72.0  -3.346568  105.666667
# 86               3.0   4.0    NaN  0.0  ...   86.0   5.478621  146.666667
# ...              ...   ...    ...  ...  ...    ...        ...         ...
# 99302           21.0   NaN   79.0  0.0  ...   75.0  25.535155  130.000000
# 99912            2.0   4.0   89.0  0.0  ...   67.0 -13.911732  174.666667
# 99912            2.0   3.0   89.0  0.0  ...   60.0 -13.911732  140.666667
# 99935           16.0   3.0  101.0  0.0  ...   86.0        NaN  135.333333
# 99935           16.0   NaN  101.0  0.0  ...   87.0        NaN  153.333333
#
#          PP       PPP   PPRatio  Score  ScoreDeath  ScoreRehosp  \
# ID
# 72     26.0  0.276596  0.250000      4           3            5
# 72     26.0  0.302326  0.282609      4           3            5
# 81     32.0  0.363636  0.457143      4           3            5
# 81     34.0  0.441558  0.472222      4           3            5
# 86     30.0  0.300000  0.348837      4           3            5
# ...     ...       ...       ...    ...         ...          ...
# 99302  55.0  0.550000  0.733333      4           3            5
# 99912  38.0  0.316667  0.567164      4           3            5
# 99912  24.0  0.255319  0.400000      4           3            5
# 99935  42.0  0.428571  0.488372      4           3            5
# 99935  70.0  0.583333  0.804598      4           3            5
#
#        ScoreReadmission
# ID
# 72                    4
# 72                    4
# 81                    4
# 81                    4
# 86                    4
# ...                 ...
# 99302                 4
# 99912                 4
# 99912                 4
# 99935                 4
# 99935                 4
#
# [866 rows x 70 columns]

# %%
# Preprocess and create training and testing sets
alld = allData.drop('Score', axis=1)
alld = alld.drop('ScoreDeath', axis=1)
alld = alld.drop('ScoreRehosp', axis=1)
alld = alld.drop('ScoreReadmission', axis=1)
alld = alld.replace(np.inf, 0)
alld = alld.fillna(0)

xData = alld
yData = death
xData.shape, yData.shape
# Out:
# ((866, 66), (866,))

# %%
mvdd= mvGen.generateTreeCrossValidation(xData=xData, yData=yData, classes=["1", "2", "3", "4", "5"], 
                                        learningCriteria='gini', maxLevels=None, minSamplesPerLeaf=1, 
                                        modelName='AC_AllData_Death', numFolds=5, 
                                        showIndividualROC=True)
# Out:
# Total edges: 42 Nonterminal Edge 20
# Must have more than 6 and less than 12 OR Edges
# Best edge set: ['dashed', 'dashed', 'dashed', 'dashed', 'dashed', 'dashed', 'dashed', 'dashed', 'dashed', 'dashed', 'dashed', 'solid', 'solid', 'solid', 'solid', 'solid', 'solid', 'dashed', 'solid', 'solid']
# Accuracy DT: 0.9540229885057471
# Accuracy MVDD: 0.8735632183908046
#
# Total edges: 36 Nonterminal Edge 17
# Must have more than 5 and less than 10 OR Edges
# Best edge set: ['dashed', 'dashed', 'dashed', 'dashed', 'dashed', 'solid', 'solid', 'solid', 'solid', 'solid', 'solid', 'dashed', 'solid', 'solid', 'solid', 'solid', 'solid']
# Accuracy DT: 0.9710982658959537
# Accuracy MVDD: 0.6936416184971098
#
# Total edges: 32 Nonterminal Edge 15
# Must have more than 4 and less than 9 OR Edges
# Best edge set: ['dashed', 'dashed', 'dashed', 'dashed', 'solid', 'solid', 'solid', 'solid', 'solid', 'solid', 'solid', 'solid', 'solid', 'dashed', 'solid']
# Accuracy DT: 0.9595375722543352
# Accuracy MVDD: 0.3930635838150289
#
# Total edges: 38 Nonterminal Edge 18
# Must have more than 5 and less than 11 OR Edges
# Best edge set: ['dashed', 'dashed', 'dashed', 'dashed', 'dashed', 'dashed', 'solid', 'dashed', 'solid', 'solid', 'solid', 'solid', 'solid', 'solid', 'solid', 'solid', 'solid', 'solid']
# Accuracy DT: 0.9421965317919075
# Accuracy MVDD: 0.9190751445086706
#
# Total edges: 38 Nonterminal Edge 18
# Must have more than 5 and less than 11 OR Edges
# Best edge set: ['dashed', 'dashed', 'dashed', 'dashed', 'dashed', 'dashed', 'dashed', 'dashed', 'solid', 'solid', 'solid', 'solid', 'solid', 'solid', 'solid', 'solid', 'solid', 'solid']
# Accuracy DT: 0.953757225433526
# Accuracy MVDD: 0.9595375722543352
# *****Averaged Final Classification Results*****
# Accuracy: 0.768(+/- 0.416)
# Precision: 0.940(+/- 0.036)
# Recall: 0.768(+/- 0.416)
# F1: 0.827(+/- 0.294)

# %% [markdown]
# # Cardiogenic Shock All Data Validation

# %%
testModel = mvGen.loadMVDDFromFile('TreeFiles/AC_AllData_Death')

# %%
allDataCohort = pd.read_csv("Data Validation/Cardiogenic Shock/Preprocessed Data/CardiogenicShock_AC_AllData.csv", sep=",", index_col='ID')
deathLabels = allDataCohort['ScoreDeath']

ad = allDataCohort.drop('ScoreDeath', axis=1)
ad = ad.drop('Score', axis=1)
ad = ad.drop('ScoreRehosp', axis=1)
ad = ad.drop('ScoreReadmission', axis=1)
ad = ad.replace(np.inf, 0)
ad = ad.fillna(0)

#get predicted scores from model
acc, recall, f1, prec = performValidation(model=testModel, data=ad, realScores=deathLabels, aucName='AllDataCardShock')
# Out:
# *****DECISION TREE*****
# DT Accuracy: 0.9907621247113164
# DT Recall: 0.9907621247113164
# DT F1 Score: 0.9907685671174578
# DT Precision: 0.9909863296995922
#
# *****MVDD*****
# Accuracy: 0.9653579676674365
# Recall: 0.9653579676674365
# F1 Score: 0.9511698729045406
# Precision: 0.9373927889980438

# %% [markdown]
# # GUIDE-IT All Data Validation

# %%
testModel = mvGen.loadMVDDFromFile('TreeFiles/AC_AllData_Death')

# %%
guideAllData = pd.read_csv("Data Validation/GUIDE-IT/Preprocessed Data/GUIDE-IT_AC_AllData.csv", sep=",", index_col='ID')
deathLabels = guideAllData['ScoreDeath']

allD = guideAllData.drop('ScoreDeath', axis=1)
allD = allD.drop('Score', axis=1)
allD = allD.drop('ScoreRehosp', axis=1)
allD = allD.drop('ScoreReadmission', axis=1)
allD = allD.replace(np.inf, 0)
allD = allD.fillna(0)

#get predicted scores from model
acc, recall, f1, prec = performValidation(model=testModel, data=allD, realScores=deathLabels, aucName='AllDataGuideIt')
# Out:
# *****DECISION TREE*****
# DT Accuracy: 0.49328859060402686
# DT Recall: 0.49328859060402686
# DT F1 Score: 0.4312451853768169
# DT Precision: 0.5065039152073126
#
# *****MVDD*****
# Accuracy: 0.12248322147651007
# Recall: 0.12248322147651007
# F1 Score: 0.026730269559896068
# Precision: 0.015002139543263819
